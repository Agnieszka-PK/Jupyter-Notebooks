# %% [markdown]
# # Funkcja print() - wyświetla zawartość nawiasiu na ekranie

# %%
print("Nowy Rok!")
# Out:
# Nowy Rok!

# %% [markdown]
# # Działania w języku Python

# %% [markdown]
# ## Przykłady z podręcznika

# %%
23+56
# Out:
# 79

# %%
987-233
# Out:
# 754

# %%
432*6
# Out:
# 2592

# %%
55//3
# Out:
# 18

# %% [markdown]
# ## Sprawdzenie

# %%
18*3
# Out:
# 54

# %% [markdown]
# ## cd przykłady z podręcznika

# %%
55/3
# Out:
# 18.333333333333332

# %%
37%4
# Out:
# 1

# %% [markdown]
# ## Sprawdzenie

# %%
37//4
# Out:
# 9

# %%
9*4
# Out:
# 36

# %%
37-36
# Out:
# 1

# %%
37%4
# Out:
# 1
